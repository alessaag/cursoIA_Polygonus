# %% [markdown]
# <a href="https://colab.research.google.com/github/alessaag/cursoIA_Polygonus/blob/main/Clase_en_VIVO_N%C2%B04_MTB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🌱 **<font color='#AECF00'>Medidas de Tendencias Central:</font>**

# %%
import numpy as np

# Datos de ejemplo
calificaciones = [70, 80, 85, 90, 95, 70, 82]

# Cálculo de medidas de tendencia central
media = np.mean(calificaciones)
mediana = np.median(calificaciones)
moda = np.argmax(np.bincount(calificaciones))

print("Media:", media)
print("Mediana:", mediana)
print("Moda:", moda)

print(f"Media: {media:.2f}")
print(f"Mediana: {mediana:.2f}")
print(f"Moda: {moda:.2f}")
# Out:
# Media: 81.71428571428571
# Mediana: 82.0
# Moda: 70
# Media: 81.71
# Mediana: 82.00
# Moda: 70.00

# %% [markdown]
# # 🌱 **<font color='#AECF00'>Medidas de tendencias dispersión</font>**

# %%
# Cálculo de medidas de dispersión
varianza = np.var(calificaciones)
desviacion_estandar = np.std(calificaciones)

print("Varianza:", varianza)
print("Desviación Estándar:", desviacion_estandar)

print(f"Varianza: {varianza:.2f}")
print(f"Desviación Estándar: {desviacion_estandar:.2f}")
# Out:
# Varianza: 76.20408163265306
# Desviación Estándar: 8.729494924258393
# Varianza: 76.20
# Desviación Estándar: 8.73

# %% [markdown]
# # 🌱 **<font color='#AECF00'>Reto propuesto:</font>**

# %% [markdown]
# > Vamos a trabajar con un nuevo conjunto de datos. Este conjunto simula las puntuaciones de un examen de matemáticas de _20_ estudiantes. Aquí están las puntuaciones: `[65, 70, 75, 80, 85, 90, 95, 100, 70, 85, 80, 90, 95, 75, 80, 85, 90, 95, 100, 60]`.

# %% [markdown]
# **Quiero que calculen las siguientes estadísticas:**
#
# * `Media`
# * `Mediana`
# * `Moda`
# * `Varianza`
# * `Desviación estándar.`

# %% [markdown]
# # 🌱 **<font color='#AECF00'>Introducción a la distribución normal:</font>**

# %%
# Importamos las bibliotecas necesarias
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Configuración de estilo para gráficos
sns.set(style="whitegrid")

# Generamos datos simulados que siguen una distribución normal
data = np.random.normal(loc=50, scale=10, size=1000)

# Cálculo de la media y la mediana
mean_value = np.mean(data)
median_value = np.median(data)

# Visualización de la distribución normal con líneas de la media y mediana
plt.figure(figsize=(10,6))
sns.histplot(data, bins=30, kde=True, color='blue')

# Añadimos las líneas de la media y la mediana
plt.axvline(mean_value, color='red', linestyle='--', linewidth=2, label=f'Media: {mean_value:.2f}')
plt.axvline(median_value, color='green', linestyle='-', linewidth=2, label=f'Mediana: {median_value:.2f}')

# Títulos y etiquetas
plt.title('Distribución normal de los datos', fontsize=16)
plt.xlabel('Valor', fontsize=12)
plt.ylabel('Frecuencia', fontsize=12)

# Mostramos la leyenda
plt.legend()

# Mostramos el gráfico
plt.show()

# Imprimimos la media y la mediana en la consola
print(f"Media de los datos: {mean_value:.2f}")
print(f"Mediana de los datos: {median_value:.2f}")
# Out:
# Media de los datos: 50.60
# Mediana de los datos: 50.51
